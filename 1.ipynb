# %%
# !pip install SpeechRecognition
# Out:
# ...
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\deepa\anaconda3\envs\ML\python.exe -m pip install --upgrade pip' command.

# %%
# !pip install xlwt
# Out:
# ...
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\deepa\anaconda3\envs\ML\python.exe -m pip install --upgrade pip' command.

# %%
#import library
import speech_recognition as sr

# Initialize recognizer class (for recognizing the speech)
r = sr.Recognizer()

# Reading Audio file as source


with sr.AudioFile('i-dont-understand.wav') as source:
    
    audio_text = r.listen(source)
    
# recoginize_() method will throw a request error if the API is unreachable, hence using exception handling
    try:
        
        # using google speech recognition
        text = r.recognize_google(audio_text)
        print('Converting audio transcripts into text ...')
        print(text)
     
    except:
         print('Sorry.. run again...')
# Out:
# Converting audio transcripts into text ...
# I don't understand

# %%
# !pip install PyAudio
# Out:
# ...
#      -------------------------------------- 164.0/164.0 KB 1.4 MB/s eta 0:00:00
# ...
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: You are using pip version 22.0.4; however, version 22.2.2 is available.
# You should consider upgrading via the 'C:\Users\deepa\anaconda3\envs\ML\python.exe -m pip install --upgrade pip' command.

# %%
#import library

import speech_recognition as sr
from datetime import datetime
from xlwt import Workbook
  
# Workbook is created
wb = Workbook()
  
# add_sheet is used to create sheet.
sheet1 = wb.add_sheet('Sheet 1')



# Initialize recognizer class (for recognizing the speech)

r = sr.Recognizer()

# Reading Microphone as source
# listening the speech and store in audio_text variable

with sr.Microphone() as source:
    start_time = datetime.now()
# do your work here

    print("Talk")
    audio_text = r.listen(source)
    print("Time over, thanks")
    end_time = datetime.now()

# recoginize_() method will throw a request error if the API is unreachable, hence using exception handling
    
    try:
        # using google speech recognition
        text=r.recognize_google(audio_text, language = "en-IN")
        print("Text: "+text)
        print('Duration: {}'.format(end_time - start_time))
        sheet1.write(1, 0, f"{start_time}")
        sheet1.write(2, 0, end_time)
        sheet1.write(3, 0, text)
        wb.save('xlwt example.xls')
        
    except:
         print("Sorry, I did not get that")
# Out:
# Talk
# Time over, thanks
# Text: hello hello hello
# Duration: 0:00:08.994574

# %%
# !pip install geolocation-python
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for geolocation-python: filename=geolocation_python-0.2.2-py3-none-any.whl size=10837 sha256=f6b48940c643c8e7b98a78027286cc37e0c94a4003670c36e3e692f3988907d3
#   Stored in directory: c:\users\deepa\appdata\local\pip\cache\wheels\e5\85\7c\59ae2bbf5f15935fb15615be9a7eeba58958c0b3113048e035
# Successfully built geolocation-python
# ...
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# WARNING: Ignoring invalid distribution -orch (c:\users\deepa\anaconda3\envs\ml\lib\site-packages)
# ...

# %%
# importing geopy library
import json
from geopy.geocoders import Nominatim
 
# calling the Nominatim tool
loc = Nominatim(user_agent="GetLoc")
 
# entering the location name
getLoc = loc.geocode("Mumbai")
 
# printing address
result=getLoc.address
sp = result.split(',')
dumpJson ={'street':sp[0], 'city': sp[1], 'state': sp[2], 
                      'zip': sp[3], 'country': sp[4]}
print(dumpJson)
 
# printing latitude and longitude
print("Location = ", dumpJson["street"],)
print("city = ", dumpJson["city"],)
print("State = ", dumpJson["state"], "\n")
print("Zip = ", dumpJson["zip"], "\n")
print("Country = ", dumpJson["country"], "\n")
print("Longitude = ", getLoc.longitude)
print("Longitude = ", getLoc.latitude)
print("Longitude = ", getLoc.point)
# Out:
# {'street': 'Mumbai', 'city': ' Mumbai Metropolitan Region', 'state': ' Mumbai Suburban', 'zip': ' Maharashtra', 'country': ' India'}
# Location =  Mumbai
#
# city =   Mumbai Metropolitan Region
#
# State =   Mumbai Suburban
#
# Zip =   Maharashtra
#
# Country =   India
#
# Longitude =  72.878176
# Longitude =  19.0785451
# Longitude =  19 4m 42.7624s N, 72 52m 41.4336s E

# %%
from geolocation.main import GoogleMaps

address = "New York City Wall Street 12"

google_maps = GoogleMaps(api_key='AIzaSyAwJHn4yNMhg9LS3gDYWkeliQfLtJwmioI') 

location = google_maps.search(location=address) # sends search to Google Maps.

print(location.all()) # returns all locations.

my_location = location.first() # returns only first location.

print(my_location.city)
print(my_location.route)
print(my_location.street_number)
print(my_location.postal_code)

for administrative_area in my_location.administrative_area:
    print("{}: {} ({})".format(administrative_area.area_type, 
                               administrative_area.name, 
                               administrative_area.short_name))

print(my_location.country)
print(my_location.country_shortcut)

print(my_location.formatted_address)

print(my_location.lat)
print(my_location.lng)
# Out:
# ---------------------------------------------------------------------------
# ApiClientException                        Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3120/172624345.py in <module>
#       5 google_maps = GoogleMaps(api_key='AIzaSyAwJHn4yNMhg9LS3gDYWkeliQfLtJwmioI')
#       6
# ----> 7 location = google_maps.search(location=address) # sends search to Google Maps.
#       8
#       9 print(location.all()) # returns all locations.
#
# c:\Users\deepa\anaconda3\envs\ML\lib\site-packages\geolocation\main.py in search(self, location, lat, lng)
#      16
#      17     def search(self, location=None, lat=None, lng=None):
# ---> 18         return self.geocode.search(location, lat, lng)
#      19
#      20     def distance(self, origins, destinations, mode=None, avoid=None):
#
# c:\Users\deepa\anaconda3\envs\ML\lib\site-packages\geolocation\geocode\main.py in search(self, address, latitude, longitude)
#      46
# ...
